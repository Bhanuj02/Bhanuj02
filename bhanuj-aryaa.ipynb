# %% [markdown]
# ## BHANUJ ARYA
# ## EN19CS303020
# # BLOCKCHAIN SIMULATOR

# %%
import hashlib                 
import datetime as date        
import random  
class Block():
    def __init__(self, height, timestamp, prev_hash, txs):
        self.height = height
        self.timestamp = timestamp
        self.prev_hash = prev_hash
        self.hash = self.hash_block()
        self.transactions = txs
        self.tx_ctr = len(txs)
        self.merkle = self.merkle_root_hash(self.transactions)
        
    def hashing(self, string):
        string = string.encode()
        sha = hashlib.sha256(string).hexdigest()
        return sha
    def hash_block(self):
        string = str(self.height) + str(self.timestamp) + str(self.prev_hash)
        return self.hashing(string)
    def merkle_root_hash(self, txs):
        if (len(txs) == 1):
            return txs[0]
        txs_new = []
        for i in range(0, len(txs)-1, 2):
            txs_new.append(self.hashing(str(txs[i]) + str(txs[i+1])))
        if len(txs)%2 == 1:
            txs_new.append(self.hashing(str(txs[-1]) + str(txs[-1])))
        return self.merkle_root_hash(txs_new)
def create_genesis_block():
    return Block(0, date.datetime.now(), "0", [random.randint(1,1000) for _ in range(10)])
def next_block(last_block):
    this_height = last_block.height + 1
    this_timestamp = date.datetime.now()
    this_hash = last_block.hash
    this_txs = [random.randint(1,100) for _ in range(10)]
    return Block(this_height, this_timestamp, this_hash, this_txs)
if __name__=="__main__":
    Myblockchain = [create_genesis_block()]
    previous_block = Myblockchain[0]
    no_of_block = 10
for i in range(1, no_of_block +1):
    block_addition = next_block(previous_block)
    Myblockchain.append(block_addition)
    previous_block = block_addition
    print(
        (f"\nBlock #{i} has been added to the Myblockchain!\n"),
        ("\t\t{}\n".format("_"*10)),
        (f"\t\tHash: {block_addition.hash}"),
        (f"| Height of Block: {block_addition.height}"),
        (f"| Timestamp: {block_addition.timestamp}"),
        (f"| Previous Root Hash: {block_addition.prev_hash}"),
        (f"| Transactions: {block_addition.transactions}"),
        (f"| Transaction Counter: {block_addition.tx_ctr}"),
        (f"| Merkle Root Hash: {block_addition.merkle}"),
        ("\t\t{}".format("_"*10))
    )
# Out:
# Block #1 has been added to the Myblockchain!
#  		__________
#  		Hash: bc99fb99d247a1eb1a1742c0fe7088c49755d7fef0dffb096e4b4867765081cd | Height of Block: 1 | Timestamp: 2021-08-20 11:00:14.037947 | Previous Root Hash: 69703751b276cf0c72cf1ed2726da58b82d4a2c20444e8d026d2c92e5d3500ba | Transactions: [57, 59, 3, 57, 23, 42, 86, 97, 21, 37] | Transaction Counter: 10 | Merkle Root Hash: e7c0b4a42a093cdfebfdc602910a72c0a1e34754eac4f6246f345d95bd0094ab 		__________
#
# Block #2 has been added to the Myblockchain!
#  		__________
#  		Hash: b35e553243587e174a9b09a006cfb2c207d6d6f4b4201f8f61da8eff0f34435b | Height of Block: 2 | Timestamp: 2021-08-20 11:00:14.040127 | Previous Root Hash: bc99fb99d247a1eb1a1742c0fe7088c49755d7fef0dffb096e4b4867765081cd | Transactions: [29, 36, 77, 32, 81, 3, 2, 1, 5, 71] | Transaction Counter: 10 | Merkle Root Hash: 675a5b68049e2971991206dd174c6a4a7e105f2163f9f078998878ffd80d2e66 		__________
#
# Block #3 has been added to the Myblockchain!
#  		__________
#  		Hash: 8c3d5c161e1b757c6d1fb7ce42fe484d0a91c5a9c5d2ffc5c2f0120ca955392b | Height of Block: 3 | Timestamp: 2021-08-20 11:00:14.040647 | Previous Root Hash: b35e553243587e174a9b09a006cfb2c207d6d6f4b4201f8f61da8eff0f34435b | Transactions: [98, 77, 62, 59, 77, 38, 32, 23, 74, 49] | Transaction Counter: 10 | Merkle Root Hash: a9b73ffd15a9bee4c391abbd5af6c5639cdb5341166d708cb0448308209f34e9 		__________
#
# Block #4 has been added to the Myblockchain!
#  		__________
#  		Hash: 88b13d854c33711b6fad3e17f8f3bb19d7b6aa8491650d928ce666560e03723e | Height of Block: 4 | Timestamp: 2021-08-20 11:00:14.041098 | Previous Root Hash: 8c3d5c161e1b757c6d1fb7ce42fe484d0a91c5a9c5d2ffc5c2f0120ca955392b | Transactions: [84, 32, 84, 66, 24, 12, 32, 40, 31, 66] | Transaction Counter: 10 | Merkle Root Hash: 18004e5c3b429cb374fb478b5a439b87164f7591956b7f58a9e37941232fd0bd 		__________
#
# Block #5 has been added to the Myblockchain!
#  		__________
#  		Hash: 2082ebb6cc688490957ac215b71464a19f468317598bafb0135e0282c8a34109 | Height of Block: 5 | Timestamp: 2021-08-20 11:00:14.041475 | Previous Root Hash: 88b13d854c33711b6fad3e17f8f3bb19d7b6aa8491650d928ce666560e03723e | Transactions: [34, 89, 78, 9, 75, 64, 28, 90, 45, 81] | Transaction Counter: 10 | Merkle Root Hash: fe274ffeca09a6225ad682a17f603b1d55ca274e6a2fee449a09a60503d9340c 		__________
#
# Block #6 has been added to the Myblockchain!
#  		__________
#  		Hash: 88c3fc472f6772f68faf89b2f19b8f6baabbcdd2e3e8f10e8ff3fd2ba5611b04 | Height of Block: 6 | Timestamp: 2021-08-20 11:00:14.045867 | Previous Root Hash: 2082ebb6cc688490957ac215b71464a19f468317598bafb0135e0282c8a34109 | Transactions: [26, 9, 91, 27, 52, 26, 76, 63, 9, 97] | Transaction Counter: 10 | Merkle Root Hash: ccebcda26498c86ec6a5d4302aa0619278c3cbf2c9c08a6141a1b8190249cc6d 		__________
#
# Block #7 has been added to the Myblockchain!
#  		__________
#  		Hash: ae464ffa32603e0bd8df781066fa8b54fc5a8fb8e2ad0fe3024df1467506d879 | Height of Block: 7 | Timestamp: 2021-08-20 11:00:14.046247 | Previous Root Hash: 88c3fc472f6772f68faf89b2f19b8f6baabbcdd2e3e8f10e8ff3fd2ba5611b04 | Transactions: [6, 80, 99, 81, 38, 68, 73, 28, 74, 10] | Transaction Counter: 10 | Merkle Root Hash: a5409bde5a237953d638d5165d94432506d05707e1733cf9a22aabff5f6e060d 		__________
#
# Block #8 has been added to the Myblockchain!
#  		__________
#  		Hash: c4700f531239c23bd1f46f01d73e30b2de5db29c5cb9a8b12a296accd8ed661b | Height of Block: 8 | Timestamp: 2021-08-20 11:00:14.046600 | Previous Root Hash: ae464ffa32603e0bd8df781066fa8b54fc5a8fb8e2ad0fe3024df1467506d879 | Transactions: [28, 10, 12, 2, 82, 97, 55, 26, 23, 83] | Transaction Counter: 10 | Merkle Root Hash: c469490fd59c80f059a9f20ea6d9825f64e73fcdf86a76484a5ed047c54b9592 		__________
#
# Block #9 has been added to the Myblockchain!
#  		__________
#  		Hash: a33d6481177508d3aea36cb62b511b15679a82163478ab8bd9756c97f4d35869 | Height of Block: 9 | Timestamp: 2021-08-20 11:00:14.046985 | Previous Root Hash: c4700f531239c23bd1f46f01d73e30b2de5db29c5cb9a8b12a296accd8ed661b | Transactions: [4, 59, 77, 41, 2, 92, 90, 97, 63, 80] | Transaction Counter: 10 | Merkle Root Hash: f1fef9ee6ee1a8ab3d53e6bdbf57eda3a6dace74eb083bdfa5182fbc009257be 		__________
#
# Block #10 has been added to the Myblockchain!
#  		__________
#  		Hash: 3f7ca7cf2beaae53c273e7b1853dd6b47f55594aa15dc8facb8f6d799e9a1454 | Height of Block: 10 | Timestamp: 2021-08-20 11:00:14.047327 | Previous Root Hash: a33d6481177508d3aea36cb62b511b15679a82163478ab8bd9756c97f4d35869 | Transactions: [59, 53, 92, 62, 4, 92, 88, 42, 94, 77] | Transaction Counter: 10 | Merkle Root Hash: cbd56a68be9c359a6d47b5af133df41dc2d74ab918269efc5be4454d060a5cf5 		__________
